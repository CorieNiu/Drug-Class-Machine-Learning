# %%
import pandas as pd 

df = pd.read_csv('GEM_.csv')

print(df)
# Out:
#               Probe  Female GEM-MIX C1  Female GEM-MIX C2  Female GEM-MIX C3  \
# 0      A_15_P100002        1903.830553         748.509049         785.565748
# 1      A_15_P100003           4.466633           5.199100           5.000000
# 2      A_15_P100007         119.649743          86.392420          38.208540
# 3      A_15_P100008         123.068325         333.115297         226.191100
# 4      A_15_P100009          18.105415          27.767469          14.938250
# ...             ...                ...                ...                ...
# 43598  WilsonLab_58          74.289892          72.627407          42.904880
# 43599  WilsonLab_61          95.918078         158.076668          71.982950
# 43600  WilsonLab_64          27.217792         121.400447          16.950950
# 43601  WilsonLab_70         105.521874         215.683531         122.220000
# 43602   WilsonLab_9        1025.807276        2132.116758         947.238747
#
# ...

# %%
df.sort_values('Probe')
# Out:
#               Probe  Female GEM-MIX C1  Female GEM-MIX C2  Female GEM-MIX C3  \
# 0      A_15_P100002        1903.830553         748.509049         785.565748
# 1      A_15_P100003           4.466633           5.199100           5.000000
# 2      A_15_P100007         119.649743          86.392420          38.208540
# 3      A_15_P100008         123.068325         333.115297         226.191100
# 4      A_15_P100009          18.105415          27.767469          14.938250
# ...             ...                ...                ...                ...
# 43598  WilsonLab_58          74.289892          72.627407          42.904880
# 43599  WilsonLab_61          95.918078         158.076668          71.982950
# 43600  WilsonLab_64          27.217792         121.400447          16.950950
# 43601  WilsonLab_70         105.521874         215.683531         122.220000
# 43602   WilsonLab_9        1025.807276        2132.116758         947.238747
#
# ...

# %%
df.describe()
# Out:
#        Female GEM-MIX C1  Female GEM-MIX C2  Female GEM-MIX C3  Female GEM H1  \
# count       43603.000000       43603.000000       43603.000000   43603.000000
# mean         1179.359419        1214.476604        1172.165806    1206.826436
# std          7113.928657        7226.763840        6849.144234    7053.896335
# min             4.466633           5.199100           5.000000      11.293619
# 25%             6.903614           5.199100           5.000000      11.293619
# 50%            28.139214          30.846127          22.690160      24.047029
# 75%           151.876051         251.010430         189.741750     241.280040
# max        176438.793900      167244.835300      137825.143700  178960.000000
#
#        Female GEM H2  Female GEM H3  Female GEM L1  Female GEM L2  \
# count   43603.000000   43603.000000   43603.000000   43603.000000
# mean     1195.051275    1149.530156    1193.242568    1191.143022
# std      6937.544518    6709.960051    6981.904481    6887.200014
# ...

# %%
>>> df_array = df.values

print(df)
# Out:
#               Probe  Female GEM-MIX C1  Female GEM-MIX C2  Female GEM-MIX C3  \
# 0      A_15_P100002        1903.830553         748.509049         785.565748
# 1      A_15_P100003           4.466633           5.199100           5.000000
# 2      A_15_P100007         119.649743          86.392420          38.208540
# 3      A_15_P100008         123.068325         333.115297         226.191100
# 4      A_15_P100009          18.105415          27.767469          14.938250
# ...             ...                ...                ...                ...
# 43598  WilsonLab_58          74.289892          72.627407          42.904880
# 43599  WilsonLab_61          95.918078         158.076668          71.982950
# 43600  WilsonLab_64          27.217792         121.400447          16.950950
# 43601  WilsonLab_70         105.521874         215.683531         122.220000
# 43602   WilsonLab_9        1025.807276        2132.116758         947.238747
#
# ...

# %%
df.select("Female GEM-MIX C1" "Female GEM-MIX C2")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e2858e7e1624> in <module>
# ----> 1 df.select("Female GEM-MIX C1" "Female GEM-MIX C2")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'select'
